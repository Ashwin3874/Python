# %%
def info():
    print('ashwin kannaujiya')

# %%
info()
# Out:
# ashwin kannaujiya

# %%
class school:
    def school_info():
        print('Ashwin kannaujiya')

# %%
obj=school
obj.school_info()
# Out:
# Ashwin kannaujiya
